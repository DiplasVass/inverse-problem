# %%
import numpy as np
from scipy import special
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from scipy.special import erf
import tensorflow as tf
import pandas as pd
import scipy.stats as stats

# %%
# Activation functions:

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0.01*x, x)

def leaky_relu(x, alpha=0.01):
    return np.maximum(alpha * x, x)

# Derivatives:

def sigmoid_derivative(x):
    sigmoid_x = sigmoid(x)
    return sigmoid_x * (1 - sigmoid_x)

def tanh_derivative(x):
    return 1 - np.tanh(x) ** 2

def relu_derivative(x):
    return np.where(x > 0, 1, 0.01)

def leaky_relu_derivative(x, alpha=0.01):
    return np.where(x > 0, 1, alpha)

# %%
# a = 0.001:
import numpy as np
from scipy.special import erf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import time
import matplotlib.pyplot as plt

# Start the timer
start_time = time.time()

np.random.seed(12)
# Define the number of data points to generate
N = 1000

# Define the parameter values
A = 10
epsilon = 0.5

x_c = np.random.uniform(0.1, 0.5, size = N)
g   = 0.3
p = g - 0.5 * A * np.sqrt(np.pi * epsilon) * (erf(x_c / np.sqrt(epsilon)) + erf((1 - x_c) / np.sqrt(epsilon)))

# Generate data points
X = p  # x = p = u'(0)
y = x_c

# Split the data: x,y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state = 301197)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

# Learning rate:
alpha = 0.001

# epochs:
epochs = 200

# Activation function choices:
function = [leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, tanh]
drv_function = [leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, 
                leaky_relu_derivative, leaky_relu_derivative, tanh_derivative]
    
# Define the neural network architecture
input_size = 1
hidden_size = [64,32,32,32,32,32]
# List of hidden layer sizes
output_size = 1

# Initialize weights and biases for each layer
np.random.seed(12)
weights = []
biases  = []

# input to hidden layer:
weights.append(0.5 - np.random.rand(hidden_size[0], input_size))
biases.append(np.zeros([hidden_size[0], 1]))
J_001 = np.zeros(epochs) # cost function

# Hidden layer:
for i in range(1, len(hidden_size)):
    weights.append(0.5 - np.random.rand(hidden_size[i], hidden_size[i-1]))
    biases.append(np.zeros([hidden_size[i], 1]))

# Output layer:
weights.append(0.5 - np.random.rand(output_size, hidden_size[-1]))
biases.append(np.zeros([output_size, 1]))

# Initialize gradients
grad_weights = [np.zeros_like(w) for w in weights]
grad_biases  = [np.zeros_like(b) for b in biases]
 
for ep in range(epochs):
    ransel = np.random.permutation(N_train)
    for i in range(N_train):
        # Forward propagation:
        # select a random without replacement:
        j = ransel[i]
        a = X_train[j]
        activations = [a]
        # Initialize z values
        zs = []
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            zs.append(z)
            a = function[k](z)   
            activations.append(a)
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        zs.append(z)
        a = function[-1](z) # output
        activations.append(a)
        
        # Backpropagation:
        delta = (activations[-1] - y_train[j]) * drv_function[-1](zs[-1])
        grad_weights[-1] = np.dot(delta, activations[-2].T)
        grad_biases[-1]  = delta
        
        # Output to hidden layers:
        for k in range(len(hidden_size) - 1, 0, -1):
            z = zs[k]
            delta = np.dot(weights[k+1].T, delta) * drv_function[k](z)
            grad_weights[k] = np.dot(delta, activations[k].T)
            grad_biases[k]  = delta
        
        # Input to Hidden layer:
        z = zs[0]
        delta = np.dot(weights[1].T, delta) * drv_function[0](z)
        grad_weights[0] = np.dot(delta, activations[0].T)
        grad_biases[0]  = delta
        
        # Gradient descent update:
        for k in range(len(hidden_size)+1):
            weights[k] -= alpha * grad_weights[k]
            biases[k]  -= alpha * grad_biases[k]
            
    for j in range(N_train):
        a = X_train[j]
        
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            a = function[k](z)   
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        a = function[-1](z) # output
        denom = 1 / (2 * N_train)
        J_001[ep] += denom*(((abs(y_train[j] - a))**2).sum())

# Test data:
y_pred_001 = np.zeros(N_test)

for k in range(N_test):
    # Forward propagation
    a = X_test[k]
        
    # Hidden layer loop:
    for l in range(len(hidden_size)):
        z = np.dot(weights[l], a) + biases[l]
        a = function[l](z)   
        
    # Hidden layer to Output:
    z = np.dot(weights[-1], a) + biases[-1]
    y_pred_001[k] = function[-1](z) # output
    
# Predict values:
# Print the predicted values for the test set
for i in range(len(X_test)):
    print(f"Test sample {i+1}: Predicted value = {y_pred_001[i]}, True value = {y_test[i]}")
    
# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Elapsed time: ", elapsed_time, " seconds")
# Out:
# Test sample 1: Predicted value = 0.2792048387626782, True value = 0.2780938089004099
# Test sample 2: Predicted value = 0.11225651081830636, True value = 0.14379416853260754
# Test sample 3: Predicted value = 0.3518088027732183, True value = 0.35749320630608106
# Test sample 4: Predicted value = 0.39488119951504846, True value = 0.4394667861173155
# Test sample 5: Predicted value = 0.38345643745916763, True value = 0.4099760861738916
# Test sample 6: Predicted value = 0.19529956323962827, True value = 0.20363226847302493
# Test sample 7: Predicted value = 0.32302531759106046, True value = 0.3230545437859139
# Test sample 8: Predicted value = 0.36076637271124934, True value = 0.3701275230267077
# Test sample 9: Predicted value = 0.32708527577419066, True value = 0.3274817932998733
# Test sample 10: Predicted value = 0.3443309503642526, True value = 0.34776938670709867
# Test sample 11: Predicted value = 0.17533668668113478, True value = 0.1883410083315542
# Test sample 12: Predicted value = 0.06913248158049977, True value = 0.11573199369157097
# Test sample 13: Predicted value = 0.3709865715235829, True value = 0.38629636664194367
# Test sample 14: Predicted value = 0.32914472222074587, True value = 0.32977311793082753
# Test sample 15: Predicted value = 0.16851220355164184, True value = 0.1832654798406484
# Test sample 16: Predicted value = 0.399732404149491, True value = 0.4578972295711563
# Test sample 17: Predicted value = 0.30359056249147715, True value = 0.30328019881463497
# Test sample 18: Predicted value = 0.1728930702156038, True value = 0.186515289802023
# Test sample 19: Predicted value = 0.09769868444458395, True value = 0.13414383533035568
# Test sample 20: Predicted value = 0.20531289687762608, True value = 0.21157986444117008
# Test sample 21: Predicted value = 0.1940421250086167, True value = 0.20264806964000137
# Test sample 22: Predicted value = 0.2208578550520656, True value = 0.22433955431585595
# Test sample 23: Predicted value = 0.2874227871295565, True value = 0.28666911717346794
# Test sample 24: Predicted value = 0.3618405366049634, True value = 0.37172861035642835
# Test sample 25: Predicted value = 0.22509015541701852, True value = 0.22791118962892837
# Test sample 26: Predicted value = 0.4031004991192773, True value = 0.47862232894512124
# Test sample 27: Predicted value = 0.14586286593668563, True value = 0.16690470062727827
# Test sample 28: Predicted value = 0.390378810937899, True value = 0.42640334621867104
# Test sample 29: Predicted value = 0.18920357958657852, True value = 0.19888835917651254
# Test sample 30: Predicted value = 0.39391277999466195, True value = 0.43642780613721854
# Test sample 31: Predicted value = 0.2572572542265177, True value = 0.2566638482611881
# Test sample 32: Predicted value = 0.40327182548940743, True value = 0.4802508288160364
# Test sample 33: Predicted value = 0.37574041604127545, True value = 0.39468160582039125
# Test sample 34: Predicted value = 0.34450340198886714, True value = 0.3479864077329762
# Test sample 35: Predicted value = 0.08226115786471926, True value = 0.12411372197339787
# Test sample 36: Predicted value = 0.11471041224903468, True value = 0.1454406878159268
# Test sample 37: Predicted value = 0.2142248327015249, True value = 0.21882846211137363
# Test sample 38: Predicted value = 0.07944606131198133, True value = 0.1223055103861642
# Test sample 39: Predicted value = 0.18524531269451702, True value = 0.19584409138000086
# Test sample 40: Predicted value = 0.3877135609883892, True value = 0.41967439420776176
# Test sample 41: Predicted value = 0.34637305561256043, True value = 0.3503601304365135
# Test sample 42: Predicted value = 0.046734761759388344, True value = 0.10171057741103273
# Test sample 43: Predicted value = 0.12080002894073481, True value = 0.14955286197009268
# Test sample 44: Predicted value = 0.40372713589228865, True value = 0.48543927366648276
# Test sample 45: Predicted value = 0.2888894073878295, True value = 0.28823611541919797
# Test sample 46: Predicted value = 0.40322085411627673, True value = 0.47975262815398956
# Test sample 47: Predicted value = 0.17854436770403442, True value = 0.19075211580779194
# Test sample 48: Predicted value = 0.1285004595817128, True value = 0.15480838306810707
# Test sample 49: Predicted value = 0.3843742855491891, True value = 0.41197536121671663
# Test sample 50: Predicted value = 0.36672468180631534, True value = 0.3792835949261758
# Test sample 51: Predicted value = 0.3334845360219446, True value = 0.3347092004290051
# Test sample 52: Predicted value = 0.13326865196893217, True value = 0.15809526703490873
# Test sample 53: Predicted value = 0.33910848333200566, True value = 0.3413422412670215
# Test sample 54: Predicted value = 0.4040811801562331, True value = 0.49142285333645497
# Test sample 55: Predicted value = 0.14177599778479363, True value = 0.1640249921863092
# Test sample 56: Predicted value = 0.29151022828453726, True value = 0.291065702308764
# Test sample 57: Predicted value = 0.10429534268890911, True value = 0.1384924156367894
# Test sample 58: Predicted value = 0.34155813529120077, True value = 0.3443228222017637
# Test sample 59: Predicted value = 0.06163230350196757, True value = 0.11099966188709631
# Test sample 60: Predicted value = 0.3702379903427316, True value = 0.38503288233842736
# Test sample 61: Predicted value = 0.3904030185344104, True value = 0.42646731921841075
# Test sample 62: Predicted value = 0.2556315088785579, True value = 0.2551502909266097
# Test sample 63: Predicted value = 0.2108323758414622, True value = 0.21604877463513086
# Test sample 64: Predicted value = 0.2687143669365405, True value = 0.2676059309935002
# Test sample 65: Predicted value = 0.12545211845559806, True value = 0.15272027349895245
# Test sample 66: Predicted value = 0.08100982799578876, True value = 0.12330919839169008
# Test sample 67: Predicted value = 0.31785516126963986, True value = 0.3175773638274054
# Test sample 68: Predicted value = 0.1436941909184368, True value = 0.16537401640487176
# Test sample 69: Predicted value = 0.25044548805547884, True value = 0.25033115812778395
# Test sample 277: Predicted value = 0.3520417072884064, True value = 0.3578070840025833
# Test sample 278: Predicted value = 0.1723934048570807, True value = 0.18614312938588282
# Test sample 279: Predicted value = 0.3495459895330326, True value = 0.3544799975331471
# Test sample 280: Predicted value = 0.3338998118378721, True value = 0.33518955267421796
# Test sample 281: Predicted value = 0.1450243189487879, True value = 0.1663121431028885
# Test sample 282: Predicted value = 0.3947393350736104, True value = 0.43901205870171667
# Test sample 283: Predicted value = 0.37812616149837175, True value = 0.3991580141308614
# Test sample 284: Predicted value = 0.0740635677664997, True value = 0.1188650652546086
# Test sample 285: Predicted value = 0.34001074115763497, True value = 0.3424332737435316
# Test sample 286: Predicted value = 0.3639507807669396, True value = 0.374935344137338
# Test sample 287: Predicted value = 0.2963383975966422, True value = 0.29638198792999315
# Test sample 288: Predicted value = 0.33655999844270557, True value = 0.3383016244298135
# Test sample 289: Predicted value = 0.0970358999198082, True value = 0.1337090678927383
# Test sample 290: Predicted value = 0.4015387644831567, True value = 0.46733064383206757
# Test sample 291: Predicted value = 0.30891771477941893, True value = 0.30849041088811713
# Test sample 292: Predicted value = 0.18637759436236337, True value = 0.19671209428562508
# Test sample 293: Predicted value = 0.34284982683462334, True value = 0.3459184666610775
# Test sample 294: Predicted value = 0.40333978942491866, True value = 0.4809353773761267
# Test sample 295: Predicted value = 0.4033079092731381, True value = 0.48061126070862836
# Test sample 296: Predicted value = 0.28982320633411834, True value = 0.28923992064389037
# Test sample 297: Predicted value = 0.40410854603005186, True value = 0.49207123936331876
# Test sample 298: Predicted value = 0.3240352084463919, True value = 0.32414502154270763
# Test sample 299: Predicted value = 0.39899465223124725, True value = 0.4546065425254321
# Test sample 300: Predicted value = 0.40373481120095733, True value = 0.4855426977118006
# Elapsed time:  33.792521238327026  seconds

# %%
# a = 0.001:
import numpy as np
from scipy.special import erf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import time
import matplotlib.pyplot as plt

# Start the timer
start_time = time.time()

np.random.seed(12)
# Define the number of data points to generate
N = 1000

# Define the parameter values
A = 10
epsilon = 0.5

x_c = np.random.uniform(0.1, 0.5, size = N)
g   = 0.3
p = g - 0.5 * A * np.sqrt(np.pi * epsilon) * (erf(x_c / np.sqrt(epsilon)) + erf((1 - x_c) / np.sqrt(epsilon)))

# Generate data points
X = p  # x = p = u'(0)
y = x_c

# Split the data: x,y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state = 301197)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

# Learning rate:
alpha = 0.01

# epochs:
epochs = 200

# Activation function choices:
function = [leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, tanh]
drv_function = [leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, 
                leaky_relu_derivative, leaky_relu_derivative, tanh_derivative]
    
# Define the neural network architecture
input_size = 1
hidden_size = [64,32,32,32,32,32]
# List of hidden layer sizes
output_size = 1

# Initialize weights and biases for each layer
np.random.seed(12)
weights = []
biases  = []

# input to hidden layer:
weights.append(0.5 - np.random.rand(hidden_size[0], input_size))
biases.append(np.zeros([hidden_size[0], 1]))
J_01 = np.zeros(epochs) # cost function

# Hidden layer:
for i in range(1, len(hidden_size)):
    weights.append(0.5 - np.random.rand(hidden_size[i], hidden_size[i-1]))
    biases.append(np.zeros([hidden_size[i], 1]))

# Output layer:
weights.append(0.5 - np.random.rand(output_size, hidden_size[-1]))
biases.append(np.zeros([output_size, 1]))

# Initialize gradients
grad_weights = [np.zeros_like(w) for w in weights]
grad_biases  = [np.zeros_like(b) for b in biases]
 
for ep in range(epochs):
    ransel = np.random.permutation(N_train)
    for i in range(N_train):
        # Forward propagation:
        # select a random without replacement:
        j = ransel[i]
        a = X_train[j]
        activations = [a]
        # Initialize z values
        zs = []
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            zs.append(z)
            a = function[k](z)   
            activations.append(a)
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        zs.append(z)
        a = function[-1](z) # output
        activations.append(a)
        
        # Backpropagation:
        delta = (activations[-1] - y_train[j]) * drv_function[-1](zs[-1])
        grad_weights[-1] = np.dot(delta, activations[-2].T)
        grad_biases[-1]  = delta
        
        # Output to hidden layers:
        for k in range(len(hidden_size) - 1, 0, -1):
            z = zs[k]
            delta = np.dot(weights[k+1].T, delta) * drv_function[k](z)
            grad_weights[k] = np.dot(delta, activations[k].T)
            grad_biases[k]  = delta
        
        # Input to Hidden layer:
        z = zs[0]
        delta = np.dot(weights[1].T, delta) * drv_function[0](z)
        grad_weights[0] = np.dot(delta, activations[0].T)
        grad_biases[0]  = delta
        
        # Gradient descent update:
        for k in range(len(hidden_size)+1):
            weights[k] -= alpha * grad_weights[k]
            biases[k]  -= alpha * grad_biases[k]
            
    for j in range(N_train):
        a = X_train[j]
        
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            a = function[k](z)   
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        a = function[-1](z) # output
        denom = 1 / (2 * N_train)
        J_01[ep] += denom*(((abs(y_train[j] - a))**2).sum())

# Test data:
y_pred_01 = np.zeros(N_test)

for k in range(N_test):
    # Forward propagation
    a = X_test[k]
        
    # Hidden layer loop:
    for l in range(len(hidden_size)):
        z = np.dot(weights[l], a) + biases[l]
        a = function[l](z)   
        
    # Hidden layer to Output:
    z = np.dot(weights[-1], a) + biases[-1]
    y_pred_01[k] = function[-1](z) # output
    
# Predict values:
# Print the predicted values for the test set
for i in range(len(X_test)):
    print(f"Test sample {i+1}: Predicted value = {y_pred_01[i]}, True value = {y_test[i]}")
    
# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Elapsed time: ", elapsed_time, " seconds")
# Out:
# Test sample 1: Predicted value = 0.28256876210951315, True value = 0.2780938089004099
# Test sample 2: Predicted value = 0.10351481699650546, True value = 0.14379416853260754
# Test sample 3: Predicted value = 0.35124673235642584, True value = 0.35749320630608106
# Test sample 4: Predicted value = 0.3903117583651614, True value = 0.4394667861173155
# Test sample 5: Predicted value = 0.3799352302460534, True value = 0.4099760861738916
# Test sample 6: Predicted value = 0.1918287726972995, True value = 0.20363226847302493
# Test sample 7: Predicted value = 0.3252160332298289, True value = 0.3230545437859139
# Test sample 8: Predicted value = 0.3593590051569948, True value = 0.3701275230267077
# Test sample 9: Predicted value = 0.3288845666792194, True value = 0.3274817932998733
# Test sample 10: Predicted value = 0.34447886714008047, True value = 0.34776938670709867
# Test sample 11: Predicted value = 0.1706042156334478, True value = 0.1883410083315542
# Test sample 12: Predicted value = 0.05765732176467928, True value = 0.11573199369157097
# Test sample 262: Predicted value = 0.39849700213215233, True value = 0.4877291744746687
# Test sample 263: Predicted value = 0.2754528133342187, True value = 0.2714645426064711
# Test sample 264: Predicted value = 0.38444401896284885, True value = 0.42140666027095053
# Test sample 265: Predicted value = 0.2612872016686934, True value = 0.2588130827469408
# Test sample 266: Predicted value = 0.3983265781558205, True value = 0.4850387612111401
# Test sample 267: Predicted value = 0.3849343056785085, True value = 0.42275262817315207
# Test sample 268: Predicted value = 0.39426312176907324, True value = 0.45562255235979376
# Test sample 269: Predicted value = 0.3943630134785295, True value = 0.4561083272970111
# Test sample 270: Predicted value = 0.3677583394606081, True value = 0.38469103508210745
# Test sample 271: Predicted value = 0.17255858330731336, True value = 0.18972050051253253
# Test sample 272: Predicted value = 0.3100797964916914, True value = 0.30587612235236544
# Test sample 273: Predicted value = 0.3018113793560351, True value = 0.2971183637396606
# Test sample 274: Predicted value = 0.35452899197659826, True value = 0.3624622345245311
# Test sample 275: Predicted value = 0.08160239764753104, True value = 0.1301918795268786
# Test sample 276: Predicted value = 0.11417095654118868, True value = 0.15055491350983896
# Test sample 277: Predicted value = 0.35145758575312686, True value = 0.3578070840025833
# Test sample 278: Predicted value = 0.16747443268560103, True value = 0.18614312938588282
# Test sample 279: Predicted value = 0.34919835688468265, True value = 0.3544799975331471
# Test sample 280: Predicted value = 0.33504433104164383, True value = 0.33518955267421796
# Test sample 281: Predicted value = 0.1383671666892862, True value = 0.1663121431028885
# Test sample 282: Predicted value = 0.39018283975543977, True value = 0.43901205870171667
# Test sample 283: Predicted value = 0.37509782384709056, True value = 0.3991580141308614
# Test sample 284: Predicted value = 0.06289978786330072, True value = 0.1188650652546086
# Test sample 285: Predicted value = 0.34057055943622994, True value = 0.3424332737435316
# Test sample 286: Predicted value = 0.362244327287816, True value = 0.374935344137338
# Test sample 287: Predicted value = 0.30109917967664396, True value = 0.29638198792999315
# Test sample 288: Predicted value = 0.3374496952608915, True value = 0.3383016244298135
# Test sample 289: Predicted value = 0.08732720876155647, True value = 0.1337090678927383
# Test sample 290: Predicted value = 0.39636384271092806, True value = 0.46733064383206757
# Test sample 291: Predicted value = 0.3124758117644754, True value = 0.30849041088811713
# Test sample 292: Predicted value = 0.18234369359575467, True value = 0.19671209428562508
# Test sample 293: Predicted value = 0.34313881928082607, True value = 0.3459184666610775
# Test sample 294: Predicted value = 0.3980017732538063, True value = 0.4809353773761267
# Test sample 295: Predicted value = 0.3979727774174956, True value = 0.48061126070862836
# Test sample 296: Predicted value = 0.29405516981523144, True value = 0.28923992064389037
# Test sample 297: Predicted value = 0.3987010065098289, True value = 0.49207123936331876
# Test sample 298: Predicted value = 0.3261284691080978, True value = 0.32414502154270763
# Test sample 299: Predicted value = 0.39405062929644835, True value = 0.4546065425254321
# Test sample 300: Predicted value = 0.39836106386163395, True value = 0.4855426977118006
# Elapsed time:  33.51349878311157  seconds

# %%
# a = 0.001:
import numpy as np
from scipy.special import erf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import time
import matplotlib.pyplot as plt

# Start the timer
start_time = time.time()

np.random.seed(12)
# Define the number of data points to generate
N = 1000

# Define the parameter values
A = 10
epsilon = 0.5

x_c = np.random.uniform(0.1, 0.5, size = N)
g   = 0.3
p = g - 0.5 * A * np.sqrt(np.pi * epsilon) * (erf(x_c / np.sqrt(epsilon)) + erf((1 - x_c) / np.sqrt(epsilon)))

# Generate data points
X = p  # x = p = u'(0)
y = x_c

# Split the data: x,y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state = 301197)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

# Learning rate:
alpha = 0.1

# epochs:
epochs = 200

# Activation function choices:
function = [leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, tanh]
drv_function = [leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, 
                leaky_relu_derivative, leaky_relu_derivative, tanh_derivative]
    
# Define the neural network architecture
input_size = 1
hidden_size = [64,32,32,32,32,32]
# List of hidden layer sizes
output_size = 1

# Initialize weights and biases for each layer
np.random.seed(12)
weights = []
biases  = []

# input to hidden layer:
weights.append(0.5 - np.random.rand(hidden_size[0], input_size))
biases.append(np.zeros([hidden_size[0], 1]))
J_1 = np.zeros(epochs) # cost function

# Hidden layer:
for i in range(1, len(hidden_size)):
    weights.append(0.5 - np.random.rand(hidden_size[i], hidden_size[i-1]))
    biases.append(np.zeros([hidden_size[i], 1]))

# Output layer:
weights.append(0.5 - np.random.rand(output_size, hidden_size[-1]))
biases.append(np.zeros([output_size, 1]))

# Initialize gradients
grad_weights = [np.zeros_like(w) for w in weights]
grad_biases  = [np.zeros_like(b) for b in biases]
 
for ep in range(epochs):
    ransel = np.random.permutation(N_train)
    for i in range(N_train):
        # Forward propagation:
        # select a random without replacement:
        j = ransel[i]
        a = X_train[j]
        activations = [a]
        # Initialize z values
        zs = []
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            zs.append(z)
            a = function[k](z)   
            activations.append(a)
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        zs.append(z)
        a = function[-1](z) # output
        activations.append(a)
        
        # Backpropagation:
        delta = (activations[-1] - y_train[j]) * drv_function[-1](zs[-1])
        grad_weights[-1] = np.dot(delta, activations[-2].T)
        grad_biases[-1]  = delta
        
        # Output to hidden layers:
        for k in range(len(hidden_size) - 1, 0, -1):
            z = zs[k]
            delta = np.dot(weights[k+1].T, delta) * drv_function[k](z)
            grad_weights[k] = np.dot(delta, activations[k].T)
            grad_biases[k]  = delta
        
        # Input to Hidden layer:
        z = zs[0]
        delta = np.dot(weights[1].T, delta) * drv_function[0](z)
        grad_weights[0] = np.dot(delta, activations[0].T)
        grad_biases[0]  = delta
        
        # Gradient descent update:
        for k in range(len(hidden_size)+1):
            weights[k] -= alpha * grad_weights[k]
            biases[k]  -= alpha * grad_biases[k]
            
    for j in range(N_train):
        a = X_train[j]
        
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            a = function[k](z)   
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        a = function[-1](z) # output
        denom = 1 / (2 * N_train)
        J_1[ep] += denom*(((abs(y_train[j] - a))**2).sum())

# Test data:
y_pred_1 = np.zeros(N_test)

for k in range(N_test):
    # Forward propagation
    a = X_test[k]
        
    # Hidden layer loop:
    for l in range(len(hidden_size)):
        z = np.dot(weights[l], a) + biases[l]
        a = function[l](z)   
        
    # Hidden layer to Output:
    z = np.dot(weights[-1], a) + biases[-1]
    y_pred_1[k] = function[-1](z) # output
    
# Predict values:
# Print the predicted values for the test set
for i in range(len(X_test)):
    print(f"Test sample {i+1}: Predicted value = {y_pred_1[i]}, True value = {y_test[i]}")
    
# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Elapsed time: ", elapsed_time, " seconds")
# Out:
# Test sample 1: Predicted value = 0.9999999996963338, True value = 0.2780938089004099
# Test sample 2: Predicted value = 0.9999999964744338, True value = 0.14379416853260754
# Test sample 3: Predicted value = 0.9999999998861702, True value = 0.35749320630608106
# Test sample 4: Predicted value = 0.9999999999363866, True value = 0.4394667861173155
# Test sample 5: Predicted value = 0.9999999999256103, True value = 0.4099760861738916
# Test sample 6: Predicted value = 0.9999999989392585, True value = 0.20363226847302493
# Test sample 7: Predicted value = 0.9999999998339518, True value = 0.3230545437859139
# Test sample 8: Predicted value = 0.9999999998989665, True value = 0.3701275230267077
# Test sample 9: Predicted value = 0.999999999842486, True value = 0.3274817932998733
# Test sample 10: Predicted value = 0.9999999998743373, True value = 0.34776938670709867
# Test sample 11: Predicted value = 0.9999999985799146, True value = 0.1883410083315542
# Test sample 12: Predicted value = 0.9999999934872715, True value = 0.11573199369157097
# Test sample 13: Predicted value = 0.9999999999119149, True value = 0.38629636664194367
# Test sample 14: Predicted value = 0.9999999998466551, True value = 0.32977311793082753
# Test sample 15: Predicted value = 0.9999999984317526, True value = 0.1832654798406484
# Test sample 16: Predicted value = 0.9999999999405063, True value = 0.4578972295711563
# Test sample 17: Predicted value = 0.999999999786686, True value = 0.30328019881463497
# Test sample 18: Predicted value = 0.9999999985285037, True value = 0.186515289802023
# Test sample 19: Predicted value = 0.9999999956604276, True value = 0.13414383533035568
# Test sample 20: Predicted value = 0.9999999990844674, True value = 0.21157986444117008
# Test sample 21: Predicted value = 0.9999999989195126, True value = 0.20264806964000137
# Test sample 22: Predicted value = 0.9999999992724421, True value = 0.22433955431585595
# Test sample 23: Predicted value = 0.9999999997318664, True value = 0.28666911717346794
# Test sample 24: Predicted value = 0.9999999999004069, True value = 0.37172861035642835
# Test sample 25: Predicted value = 0.9999999993167629, True value = 0.22791118962892837
# Test sample 26: Predicted value = 0.9999999999432189, True value = 0.47862232894512124
# Test sample 27: Predicted value = 0.9999999978235351, True value = 0.16690470062727827
# Test sample 28: Predicted value = 0.9999999999323266, True value = 0.42640334621867104
# Test sample 29: Predicted value = 0.9999999988401422, True value = 0.19888835917651254
# Test sample 30: Predicted value = 0.999999999935533, True value = 0.43642780613721854
# Test sample 31: Predicted value = 0.9999999995778687, True value = 0.2566638482611881
# Test sample 32: Predicted value = 0.9999999999433538, True value = 0.4802508288160364
# Test sample 33: Predicted value = 0.9999999999173926, True value = 0.39468160582039125
# Test sample 34: Predicted value = 0.9999999998746227, True value = 0.3479864077329762
# Test sample 35: Predicted value = 0.9999999945945124, True value = 0.12411372197339787
# Test sample 36: Predicted value = 0.9999999965959718, True value = 0.1454406878159268
# Test sample 37: Predicted value = 0.999999999197325, True value = 0.21882846211137363
# Test sample 38: Predicted value = 0.9999999943739755, True value = 0.1223055103861642
# Test sample 164: Predicted value = 0.9999999998663602, True value = 0.34200215614542545
# Test sample 165: Predicted value = 0.9999999999420577, True value = 0.4679459483849294
# Test sample 166: Predicted value = 0.9999999999438194, True value = 0.4874473315879867
# Test sample 167: Predicted value = 0.9999999993528782, True value = 0.23102779050536923
# Test sample 168: Predicted value = 0.9999999999379292, True value = 0.44550073033572446
# Test sample 169: Predicted value = 0.9999999997518509, True value = 0.29216250064408633
# Test sample 170: Predicted value = 0.999999999923585, True value = 0.40582418013555155
# Test sample 171: Predicted value = 0.9999999999337833, True value = 0.4307199900642703
# Test sample 172: Predicted value = 0.9999999980746694, True value = 0.17295659005888692
# Test sample 173: Predicted value = 0.9999999999435074, True value = 0.48229372537255133
# Test sample 174: Predicted value = 0.9999999955647572, True value = 0.13314030909011057
# Test sample 175: Predicted value = 0.9999999995922515, True value = 0.25884261242078793
# Test sample 176: Predicted value = 0.9999999999321361, True value = 0.42586375771223217
# Test sample 177: Predicted value = 0.9999999999408633, True value = 0.45996488324221485
# Test sample 178: Predicted value = 0.9999999999378052, True value = 0.444986064919046
# Test sample 179: Predicted value = 0.9999999947787798, True value = 0.1256864085431596
# Test sample 180: Predicted value = 0.9999999951863575, True value = 0.1293880175769062
# Test sample 181: Predicted value = 0.999999999933881, True value = 0.4310226024876005
# Test sample 182: Predicted value = 0.9999999999437058, True value = 0.48535526421475916
# Test sample 183: Predicted value = 0.9999999998950581, True value = 0.3659835053332303
# Test sample 184: Predicted value = 0.9999999999237197, True value = 0.4060914913092982
# Test sample 185: Predicted value = 0.9999999997874565, True value = 0.3035530320659272
# Test sample 186: Predicted value = 0.9999999960879424, True value = 0.13894094877783414
# Test sample 187: Predicted value = 0.9999999971634889, True value = 0.15408407134764676
# Test sample 188: Predicted value = 0.9999999967594899, True value = 0.1477597376320564
# Test sample 189: Predicted value = 0.9999999999424499, True value = 0.4710859970886371
# Test sample 190: Predicted value = 0.9999999994969903, True value = 0.24588718500279128
# Test sample 191: Predicted value = 0.9999999999420781, True value = 0.4681012608264219
# Test sample 192: Predicted value = 0.9999999995821458, True value = 0.2573021970940318
# Test sample 193: Predicted value = 0.9999999999432978, True value = 0.4795585554476639
# Test sample 194: Predicted value = 0.9999999997566579, True value = 0.2935702357856638
# Test sample 195: Predicted value = 0.999999999919491, True value = 0.39822950687041647
# Test sample 196: Predicted value = 0.9999999999441325, True value = 0.4995161635498556
# Test sample 197: Predicted value = 0.9999999988964325, True value = 0.20152327757107577
# Test sample 198: Predicted value = 0.9999999999360598, True value = 0.4382810087379273
# Test sample 199: Predicted value = 0.9999999999434658, True value = 0.48171727424975563
# Test sample 200: Predicted value = 0.9999999988507876, True value = 0.1993753957099234
# Test sample 201: Predicted value = 0.9999999979982067, True value = 0.17102567037515573
# Test sample 202: Predicted value = 0.9999999997378332, True value = 0.28825226319310493
# Test sample 203: Predicted value = 0.9999999997174863, True value = 0.2830331793659041
# Test sample 204: Predicted value = 0.9999999990064644, True value = 0.2071453135177396
# Test sample 205: Predicted value = 0.9999999999437251, True value = 0.4856888094026157
# Test sample 289: Predicted value = 0.9999999956192558, True value = 0.1337090678927383
# Test sample 290: Predicted value = 0.9999999999419757, True value = 0.46733064383206757
# Test sample 291: Predicted value = 0.9999999998007739, True value = 0.30849041088811713
# Test sample 292: Predicted value = 0.9999999987911907, True value = 0.19671209428562508
# Test sample 293: Predicted value = 0.9999999998718604, True value = 0.3459184666610775
# Test sample 294: Predicted value = 0.9999999999434072, True value = 0.4809353773761267
# Test sample 295: Predicted value = 0.9999999999433821, True value = 0.48061126070862836
# Test sample 296: Predicted value = 0.9999999997414689, True value = 0.28923992064389037
# Test sample 297: Predicted value = 0.9999999999440081, True value = 0.49207123936331876
# Test sample 298: Predicted value = 0.9999999998361145, True value = 0.32414502154270763
# Test sample 299: Predicted value = 0.9999999999398963, True value = 0.4546065425254321
# Test sample 300: Predicted value = 0.9999999999437167, True value = 0.4855426977118006
# Elapsed time:  33.48849415779114  seconds

# %%
# Graphs for learning rate:
print(np.min(J_001))
print(np.min(J_01))
print(np.min(J_1))

plt.plot([1, 2, 3],[np.min(J_001),np.min(J_01),np.min(J_1)],color = 'black',marker = 'o')
# Add title and labels to the plot
plt.title('Learning Rates for the minimum cost')
# Set custom tick labels on the x-axis with LaTeX formatting
plt.xticks([1, 2, 3],[r'$\alpha = 0.001$', r'$\alpha = 0.01$', r'$\alpha = 0.1$'])
plt.ylabel('Cost')
plt.show()
# Out:
# 0.0003122257918734874
# 0.00040333786643222136
# 0.25003776718106413

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (19,3))

for ax in enumerate(axes.flatten()):
    axes[0].plot(range(epochs),J_001,color='black',marker = 'o')
    axes[0].set_xlabel("epoch")
    axes[0].set_ylabel('Cost')
    axes[0].set_title(r'$\alpha$ = 0.001')
    
    axes[1].plot(range(epochs),J_01,color='black',marker='o')
    axes[1].set_xlabel("epoch")
    axes[1].set_ylabel('Cost')
    axes[1].set_title(r'$\alpha$ = 0.01')
    
    axes[2].plot(range(epochs),J_1,color='black')
    axes[2].set_xlabel("epoch")
    axes[2].set_ylabel('Cost')
    axes[2].set_title(r'$\alpha$ = 0.1')
    
# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.4)

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize = (19,8))

for ax in enumerate(axes.flatten()):
    
    axes[0,0].hist(y_pred_001,color='black',bins=np.linspace(0,0.5 , 100), linewidth=0.75,histtype=u'step')
    axes[0,0].set_title(r"Empirical distribution for $\alpha = 0.001$")
    axes[0,0].set_xlabel('Predictions')
    
    axes[0,1].hist(y_pred_01,color='black',bins=np.linspace(0,0.5 , 100), linewidth=0.75,histtype=u'step')
    axes[0,1].set_title(r"Empirical distribution for $\alpha = 0.01$")
    axes[0,1].set_xlabel('Predictions')
    
    axes[0,2].hist(y_pred_1,color='black',bins=np.linspace(0,0.5 , 100), linewidth=0.75,histtype=u'step')
    axes[0,2].set_title(r"Empirical distribution for $\alpha = 0.1$")
    axes[0,2].set_xlabel('Predictions')
  
    axes[1,0].hist(np.abs(y_test - y_pred_001),color='black',bins=np.linspace(0,0.24 , 100), linewidth=0.75,histtype=u'step')
    axes[1,0].set_title(r"Error distribution for $\alpha = 0.001$")
    axes[1,0].set_xlabel('Predictions')

    axes[1,1].hist(np.abs(y_test - y_pred_01),color='black',bins=np.linspace(0,0.24 , 100), linewidth=0.75,histtype=u'step')
    axes[1,1].set_title(r"Error distribution for $\alpha = 0.01$")
    axes[1,1].set_xlabel('Predictions')

    axes[1,2].hist(np.abs(y_test - y_pred_1),color='black',bins=np.linspace(0,0.24 , 100), linewidth=0.75,histtype=u'step')
    axes[1,2].set_title(r"Error distribution for $\alpha = 0.1$")
    axes[1,2].set_xlabel('Predictions')

    
# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.7)
plt.subplots_adjust(hspace=0.7)

# %%
print('The mean for a = 0.1 =',format(np.mean(y_pred_1),".5f"))
print('The mean for a = 0.01 =',format(np.mean(y_pred_01),".5f"))
print('The mean for a = 0.001 =',format(np.mean(y_pred_001),".5f"))

print('The variance for a = 0.1 ='  , format(np.var(y_pred_1),".5f"))
print('The variance for a = 0.01 =' , format(np.var(y_pred_01),".5f"))
print('The variance for a = 0.001 =', format(np.var(y_pred_001),".5f"))
# Out:
# The mean for a = 0.1 = 1.00000
# The mean for a = 0.01 = 0.28414
# The mean for a = 0.001 = 0.28704
# The variance for a = 0.1 = 0.00000
# The variance for a = 0.01 = 0.01196
# The variance for a = 0.001 = 0.01156

# %%
# We can choose either 0.001 or 0.01. We prefer 0.01.

# %%
# For the number of epochs we can choose epochs less than 200 
# because the cost function is steady after 25th epoch to both of the plots.
# Suppose we choose 100 epochs.

# a = 0.001:
import numpy as np
from scipy.special import erf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import time
import matplotlib.pyplot as plt

# Start the timer
start_time = time.time()

np.random.seed(12)
# Define the number of data points to generate
N = 1000

# Define the parameter values
A = 10
epsilon = 0.5

x_c = np.random.uniform(0.1, 0.5, size = N)
g   = 0.3
p = g - 0.5 * A * np.sqrt(np.pi * epsilon) * (erf(x_c / np.sqrt(epsilon)) + erf((1 - x_c) / np.sqrt(epsilon)))

# Generate data points
X = p  # x = p = u'(0)
y = x_c

# Split the data: x,y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state = 301197)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

# Learning rate:
alpha = 0.01

# epochs:
epochs = 100

# Activation function choices:
function = [leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, leaky_relu, tanh]
drv_function = [leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, leaky_relu_derivative, 
                leaky_relu_derivative, leaky_relu_derivative, tanh_derivative]
    
# Define the neural network architecture
input_size = 1
hidden_size = [64,32,32,32,32,32]
# List of hidden layer sizes
output_size = 1

# Initialize weights and biases for each layer
np.random.seed(12)
weights = []
biases  = []

# input to hidden layer:
weights.append(0.5 - np.random.rand(hidden_size[0], input_size))
biases.append(np.zeros([hidden_size[0], 1]))
J = np.zeros(epochs) # cost function

# Hidden layer:
for i in range(1, len(hidden_size)):
    weights.append(0.5 - np.random.rand(hidden_size[i], hidden_size[i-1]))
    biases.append(np.zeros([hidden_size[i], 1]))

# Output layer:
weights.append(0.5 - np.random.rand(output_size, hidden_size[-1]))
biases.append(np.zeros([output_size, 1]))

# Initialize gradients
grad_weights = [np.zeros_like(w) for w in weights]
grad_biases  = [np.zeros_like(b) for b in biases]
 
for ep in range(epochs):
    ransel = np.random.permutation(N_train)
    for i in range(N_train):
        # Forward propagation:
        # select a random without replacement:
        j = ransel[i]
        a = X_train[j]
        activations = [a]
        # Initialize z values
        zs = []
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            zs.append(z)
            a = function[k](z)   
            activations.append(a)
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        zs.append(z)
        a = function[-1](z) # output
        activations.append(a)
        
        # Backpropagation:
        delta = (activations[-1] - y_train[j]) * drv_function[-1](zs[-1])
        grad_weights[-1] = np.dot(delta, activations[-2].T)
        grad_biases[-1]  = delta
        
        # Output to hidden layers:
        for k in range(len(hidden_size) - 1, 0, -1):
            z = zs[k]
            delta = np.dot(weights[k+1].T, delta) * drv_function[k](z)
            grad_weights[k] = np.dot(delta, activations[k].T)
            grad_biases[k]  = delta
        
        # Input to Hidden layer:
        z = zs[0]
        delta = np.dot(weights[1].T, delta) * drv_function[0](z)
        grad_weights[0] = np.dot(delta, activations[0].T)
        grad_biases[0]  = delta
        
        # Gradient descent update:
        for k in range(len(hidden_size)+1):
            weights[k] -= alpha * grad_weights[k]
            biases[k]  -= alpha * grad_biases[k]
            
    for j in range(N_train):
        a = X_train[j]
        
        # Hidden layer loop:
        for k in range(len(hidden_size)):
            z = np.dot(weights[k], a) + biases[k]
            a = function[k](z)   
        
        # Hidden layer to Output:
        z = np.dot(weights[-1], a) + biases[-1]
        a = function[-1](z) # output
        denom = 1 / (2 * N_train)
        J[ep] += denom*(((abs(y_train[j] - a))**2).sum())

# Test data:
y_pred_01_100 = np.zeros(N_test)

for k in range(N_test):
    # Forward propagation
    a = X_test[k]
        
    # Hidden layer loop:
    for l in range(len(hidden_size)):
        z = np.dot(weights[l], a) + biases[l]
        a = function[l](z)   
        
    # Hidden layer to Output:
    z = np.dot(weights[-1], a) + biases[-1]
    y_pred_01_100[k] = function[-1](z) # output
    
# Predict values:
# Print the predicted values for the test set
for i in range(len(X_test)):
    print(f"Test sample {i+1}: Predicted value = {y_pred_01_100[i]}, True value = {y_test[i]}")
    
# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Elapsed time: ", elapsed_time, " seconds")
# Out:
# Test sample 1: Predicted value = 0.28764033928280414, True value = 0.2780938089004099
# Test sample 2: Predicted value = 0.10823884907942885, True value = 0.14379416853260754
# Test sample 3: Predicted value = 0.35544058618606594, True value = 0.35749320630608106
# Test sample 4: Predicted value = 0.39400156363853706, True value = 0.4394667861173155
# Test sample 5: Predicted value = 0.38375902469082623, True value = 0.4099760861738916
# Test sample 6: Predicted value = 0.19760261951703764, True value = 0.20363226847302493
# Test sample 7: Predicted value = 0.3297444043453299, True value = 0.3230545437859139
# Test sample 8: Predicted value = 0.36344831792712856, True value = 0.3701275230267077
# Test sample 9: Predicted value = 0.33336590018568807, True value = 0.3274817932998733
# Test sample 10: Predicted value = 0.3487598466608094, True value = 0.34776938670709867
# Test sample 11: Predicted value = 0.1761368816596632, True value = 0.1883410083315542
# Test sample 12: Predicted value = 0.06179476766004632, True value = 0.11573199369157097
# Test sample 179: Predicted value = 0.07856289793637464, True value = 0.1256864085431596
# Test sample 180: Predicted value = 0.08471828602392238, True value = 0.1293880175769062
# Test sample 181: Predicted value = 0.3914820696469269, True value = 0.4310226024876005
# Test sample 182: Predicted value = 0.4019344143926037, True value = 0.48535526421475916
# Test sample 183: Predicted value = 0.3609054317669322, True value = 0.3659835053332303
# Test sample 184: Predicted value = 0.3821075170340463, True value = 0.4060914913092982
# Test sample 185: Predicted value = 0.3126723152689108, True value = 0.3035530320659272
# Test sample 186: Predicted value = 0.10039433385534915, True value = 0.13894094877783414
# Test sample 187: Predicted value = 0.12459377419544093, True value = 0.15408407134764676
# Test sample 188: Predicted value = 0.11458700515118504, True value = 0.1477597376320564
# Test sample 189: Predicted value = 0.40050686249913126, True value = 0.4710859970886371
# Test sample 190: Predicted value = 0.25160131468353825, True value = 0.24588718500279128
# Test sample 191: Predicted value = 0.40008983416656113, True value = 0.4681012608264219
# Test sample 192: Predicted value = 0.2649056644554362, True value = 0.2573021970940318
# Test sample 193: Predicted value = 0.40146737439399266, True value = 0.4795585554476639
# Test sample 194: Predicted value = 0.3032269168478232, True value = 0.2935702357856638
# Test sample 195: Predicted value = 0.3785486641794336, True value = 0.39822950687041647
# Test sample 196: Predicted value = 0.40242628011348247, True value = 0.4995161635498556
# Test sample 197: Predicted value = 0.1947010841886984, True value = 0.20152327757107577
# Test sample 198: Predicted value = 0.3936677194831275, True value = 0.4382810087379273
# Test sample 199: Predicted value = 0.40165934610468884, True value = 0.48171727424975563
# Test sample 200: Predicted value = 0.19172645690858647, True value = 0.1993753957099234
# Test sample 201: Predicted value = 0.15066150046356114, True value = 0.17102567037515573
# Test sample 202: Predicted value = 0.2980002563738086, True value = 0.28825226319310493
# Test sample 203: Predicted value = 0.29273923205440966, True value = 0.2830331793659041
# Test sample 204: Predicted value = 0.20239329607281326, True value = 0.2071453135177396
# Test sample 205: Predicted value = 0.4019565906643533, True value = 0.4856888094026157
# Test sample 206: Predicted value = 0.08807938321257207, True value = 0.13142068444902671
# Test sample 207: Predicted value = 0.04481929762849562, True value = 0.10582998499416787
# Test sample 208: Predicted value = 0.2053003671568784, True value = 0.20929644675331224
# Test sample 209: Predicted value = 0.2032779333709461, True value = 0.2077983424691869
# Test sample 210: Predicted value = 0.3729341989594847, True value = 0.38694749014480156
# Test sample 211: Predicted value = 0.38927727961160874, True value = 0.42440826633986684
# Test sample 212: Predicted value = 0.30171602556755206, True value = 0.29201871333075613
# Test sample 213: Predicted value = 0.33797214742210885, True value = 0.3332870208661241
# Test sample 214: Predicted value = 0.3547472024869375, True value = 0.3564526262360367
# Test sample 215: Predicted value = 0.40230228856739153, True value = 0.4926350218774548
# Test sample 216: Predicted value = 0.35483171162869487, True value = 0.3565790382462466
# Test sample 217: Predicted value = 0.40150403539717555, True value = 0.4799528308551001
# Test sample 218: Predicted value = 0.34827810236016127, True value = 0.34709265670359357
# Test sample 219: Predicted value = 0.3647963598979888, True value = 0.3723800804842198
# Test sample 220: Predicted value = 0.3754074535849798, True value = 0.3917700484674054
# Test sample 262: Predicted value = 0.4020811224283, True value = 0.4877291744746687
# Test sample 263: Predicted value = 0.28061423647219796, True value = 0.2714645426064711
# Test sample 264: Predicted value = 0.3882095943876899, True value = 0.42140666027095053
# Test sample 265: Predicted value = 0.2666266633417306, True value = 0.2588130827469408
# Test sample 266: Predicted value = 0.40191289860857893, True value = 0.4850387612111401
# Test sample 267: Predicted value = 0.388693550083595, True value = 0.42275262817315207
# Test sample 268: Predicted value = 0.3979019053847082, True value = 0.45562255235979376
# Test sample 269: Predicted value = 0.398000507309717, True value = 0.4561083272970111
# Test sample 270: Predicted value = 0.3717393139570799, True value = 0.38469103508210745
# Test sample 271: Predicted value = 0.17811377657277547, True value = 0.18972050051253253
# Test sample 272: Predicted value = 0.31480178240181894, True value = 0.30587612235236544
# Test sample 273: Predicted value = 0.3066387768871176, True value = 0.2971183637396606
# Test sample 274: Predicted value = 0.3586805609709505, True value = 0.3624622345245311
# Test sample 275: Predicted value = 0.08604912965136803, True value = 0.1301918795268786
# Test sample 276: Predicted value = 0.11902767899186258, True value = 0.15055491350983896
# Test sample 277: Predicted value = 0.35564872376096035, True value = 0.3578070840025833
# Test sample 278: Predicted value = 0.17297089181987876, True value = 0.18614312938588282
# Test sample 279: Predicted value = 0.3534185898130632, True value = 0.3544799975331471
# Test sample 280: Predicted value = 0.3394465984096963, True value = 0.33518955267421796
# Test sample 281: Predicted value = 0.14351947707956336, True value = 0.1663121431028885
# Test sample 282: Predicted value = 0.3938743097375037, True value = 0.43901205870171667
# Test sample 283: Predicted value = 0.3789840717513361, True value = 0.3991580141308614
# Test sample 284: Predicted value = 0.06710547021279281, True value = 0.1188650652546086
# Test sample 285: Predicted value = 0.3449018085587153, True value = 0.3424332737435316
# Test sample 286: Predicted value = 0.36629643370636994, True value = 0.374935344137338
# Test sample 287: Predicted value = 0.30593564396579814, True value = 0.29638198792999315
# Test sample 288: Predicted value = 0.3418210602631427, True value = 0.3383016244298135
# Test sample 289: Predicted value = 0.09184694197215096, True value = 0.1337090678927383
# Test sample 290: Predicted value = 0.3999755030179914, True value = 0.46733064383206757
# Test sample 291: Predicted value = 0.31716720238973034, True value = 0.30849041088811713
# Test sample 292: Predicted value = 0.18801071306706013, True value = 0.19671209428562508
# Test sample 293: Predicted value = 0.34743703865548903, True value = 0.3459184666610775
# Test sample 294: Predicted value = 0.4015922869515077, True value = 0.4809353773761267
# Test sample 295: Predicted value = 0.40156366545554345, True value = 0.48061126070862836
# Test sample 296: Predicted value = 0.2989811923359755, True value = 0.28923992064389037
# Test sample 297: Predicted value = 0.40228249315199244, True value = 0.49207123936331876
# Test sample 298: Predicted value = 0.33064514480825463, True value = 0.32414502154270763
# Test sample 299: Predicted value = 0.3976921565899425, True value = 0.4546065425254321
# Test sample 300: Predicted value = 0.40194693910600193, True value = 0.4855426977118006
# Elapsed time:  17.241284608840942  seconds

# %%
print(np.mean(np.abs(y_pred_01_100 - y_test)))
print(np.mean(np.abs(y_pred_01 - y_test)))
# Out:
# 0.027263130738111284
# 0.029083579399107298
